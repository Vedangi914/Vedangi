# %% [markdown]
# <a href="https://colab.research.google.com/github/Vedangi914/Vedangi/blob/main/brain_tumor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IMPORTANT: RUN THIS CELL IN ORDER TO IMPORT YOUR KAGGLE DATA SOURCES,
# THEN FEEL FREE TO DELETE THIS CELL.
# NOTE: THIS NOTEBOOK ENVIRONMENT DIFFERS FROM KAGGLE'S PYTHON
# ENVIRONMENT SO THERE MAY BE MISSING LIBRARIES USED BY YOUR
# NOTEBOOK.
import kagglehub
aryashah2k_brain_tumor_segmentation_brats_2019_path = kagglehub.dataset_download('aryashah2k/brain-tumor-segmentation-brats-2019')

print('Data source import complete.')

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/name_mapping.csv
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/survival_data.csv
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_27_1/BraTS19_2013_27_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_27_1/BraTS19_2013_27_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_27_1/BraTS19_2013_27_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_27_1/BraTS19_2013_27_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_27_1/BraTS19_2013_27_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQA_1/BraTS19_CBICA_AQA_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQA_1/BraTS19_CBICA_AQA_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQA_1/BraTS19_CBICA_AQA_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQA_1/BraTS19_CBICA_AQA_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQA_1/BraTS19_CBICA_AQA_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANZ_1/BraTS19_CBICA_ANZ_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANZ_1/BraTS19_CBICA_ANZ_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANZ_1/BraTS19_CBICA_ANZ_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANZ_1/BraTS19_CBICA_ANZ_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANZ_1/BraTS19_CBICA_ANZ_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_2_1/BraTS19_2013_2_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_2_1/BraTS19_2013_2_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_2_1/BraTS19_2013_2_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_2_1/BraTS19_2013_2_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_2_1/BraTS19_2013_2_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASH_1/BraTS19_CBICA_ASH_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASH_1/BraTS19_CBICA_ASH_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASH_1/BraTS19_CBICA_ASH_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASH_1/BraTS19_CBICA_ASH_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASH_1/BraTS19_CBICA_ASH_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYA_1/BraTS19_CBICA_AYA_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYA_1/BraTS19_CBICA_AYA_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYA_1/BraTS19_CBICA_AYA_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYA_1/BraTS19_CBICA_AYA_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYA_1/BraTS19_CBICA_AYA_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_331_1/BraTS19_TCIA02_331_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_331_1/BraTS19_TCIA02_331_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_331_1/BraTS19_TCIA02_331_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_331_1/BraTS19_TCIA02_331_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_331_1/BraTS19_TCIA02_331_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA08_242_1/BraTS19_TCIA08_242_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA08_242_1/BraTS19_TCIA08_242_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA08_242_1/BraTS19_TCIA08_242_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA08_242_1/BraTS19_TCIA08_242_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA08_242_1/BraTS19_TCIA08_242_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AAP_1/BraTS19_CBICA_AAP_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AAP_1/BraTS19_CBICA_AAP_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AAP_1/BraTS19_CBICA_AAP_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AAP_1/BraTS19_CBICA_AAP_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AAP_1/BraTS19_CBICA_AAP_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_314_1/BraTS19_TCIA02_314_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_314_1/BraTS19_TCIA02_314_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_314_1/BraTS19_TCIA02_314_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_314_1/BraTS19_TCIA02_314_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_314_1/BraTS19_TCIA02_314_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABB_1/BraTS19_CBICA_ABB_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABB_1/BraTS19_CBICA_ABB_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABB_1/BraTS19_CBICA_ABB_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABB_1/BraTS19_CBICA_ABB_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABB_1/BraTS19_CBICA_ABB_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_412_1/BraTS19_TCIA01_412_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_412_1/BraTS19_TCIA01_412_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_412_1/BraTS19_TCIA01_412_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_412_1/BraTS19_TCIA01_412_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_412_1/BraTS19_TCIA01_412_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQP_1/BraTS19_CBICA_AQP_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQP_1/BraTS19_CBICA_AQP_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQP_1/BraTS19_CBICA_AQP_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQP_1/BraTS19_CBICA_AQP_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQP_1/BraTS19_CBICA_AQP_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_APR_1/BraTS19_CBICA_APR_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_APR_1/BraTS19_CBICA_APR_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_APR_1/BraTS19_CBICA_APR_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_APR_1/BraTS19_CBICA_APR_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_APR_1/BraTS19_CBICA_APR_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_222_1/BraTS19_TCIA02_222_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_222_1/BraTS19_TCIA02_222_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_222_1/BraTS19_TCIA02_222_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_222_1/BraTS19_TCIA02_222_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_222_1/BraTS19_TCIA02_222_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_199_1/BraTS19_TCIA03_199_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_199_1/BraTS19_TCIA03_199_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_199_1/BraTS19_TCIA03_199_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_199_1/BraTS19_TCIA03_199_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_199_1/BraTS19_TCIA03_199_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_3_1/BraTS19_2013_3_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_3_1/BraTS19_2013_3_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_3_1/BraTS19_2013_3_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_3_1/BraTS19_2013_3_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_3_1/BraTS19_2013_3_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AXW_1/BraTS19_CBICA_AXW_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AXW_1/BraTS19_CBICA_AXW_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AXW_1/BraTS19_CBICA_AXW_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AXW_1/BraTS19_CBICA_AXW_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AXW_1/BraTS19_CBICA_AXW_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_343_1/BraTS19_TCIA04_343_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_343_1/BraTS19_TCIA04_343_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_343_1/BraTS19_TCIA04_343_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_343_1/BraTS19_TCIA04_343_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_343_1/BraTS19_TCIA04_343_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARZ_1/BraTS19_CBICA_ARZ_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARZ_1/BraTS19_CBICA_ARZ_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARZ_1/BraTS19_CBICA_ARZ_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARZ_1/BraTS19_CBICA_ARZ_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARZ_1/BraTS19_CBICA_ARZ_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGN_1/BraTS19_CBICA_BGN_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGN_1/BraTS19_CBICA_BGN_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGN_1/BraTS19_CBICA_BGN_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGN_1/BraTS19_CBICA_BGN_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGN_1/BraTS19_CBICA_BGN_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_138_1/BraTS19_TCIA03_138_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_138_1/BraTS19_TCIA03_138_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_138_1/BraTS19_TCIA03_138_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_138_1/BraTS19_TCIA03_138_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_138_1/BraTS19_TCIA03_138_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGR_1/BraTS19_CBICA_BGR_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGR_1/BraTS19_CBICA_BGR_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGR_1/BraTS19_CBICA_BGR_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGR_1/BraTS19_CBICA_BGR_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGR_1/BraTS19_CBICA_BGR_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATD_1/BraTS19_CBICA_ATD_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATD_1/BraTS19_CBICA_ATD_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATD_1/BraTS19_CBICA_ATD_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATD_1/BraTS19_CBICA_ATD_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATD_1/BraTS19_CBICA_ATD_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQZ_1/BraTS19_CBICA_AQZ_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQZ_1/BraTS19_CBICA_AQZ_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQZ_1/BraTS19_CBICA_AQZ_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQZ_1/BraTS19_CBICA_AQZ_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQZ_1/BraTS19_CBICA_AQZ_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVF_1/BraTS19_CBICA_AVF_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVF_1/BraTS19_CBICA_AVF_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVF_1/BraTS19_CBICA_AVF_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVF_1/BraTS19_CBICA_AVF_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVF_1/BraTS19_CBICA_AVF_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AWG_1/BraTS19_CBICA_AWG_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AWG_1/BraTS19_CBICA_AWG_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AWG_1/BraTS19_CBICA_AWG_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AWG_1/BraTS19_CBICA_AWG_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AWG_1/BraTS19_CBICA_AWG_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_226_1/BraTS19_TCIA02_226_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_226_1/BraTS19_TCIA02_226_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_226_1/BraTS19_TCIA02_226_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_226_1/BraTS19_TCIA02_226_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_226_1/BraTS19_TCIA02_226_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_321_1/BraTS19_TCIA02_321_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_321_1/BraTS19_TCIA02_321_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_321_1/BraTS19_TCIA02_321_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_321_1/BraTS19_TCIA02_321_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_321_1/BraTS19_TCIA02_321_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATN_1/BraTS19_CBICA_ATN_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATN_1/BraTS19_CBICA_ATN_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATN_1/BraTS19_CBICA_ATN_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATN_1/BraTS19_CBICA_ATN_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ATN_1/BraTS19_CBICA_ATN_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_444_1/BraTS19_TCIA05_444_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_444_1/BraTS19_TCIA05_444_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_444_1/BraTS19_TCIA05_444_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_444_1/BraTS19_TCIA05_444_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_444_1/BraTS19_TCIA05_444_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA06_372_1/BraTS19_TCIA06_372_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA06_372_1/BraTS19_TCIA06_372_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA06_372_1/BraTS19_TCIA06_372_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA06_372_1/BraTS19_TCIA06_372_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA06_372_1/BraTS19_TCIA06_372_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVV_1/BraTS19_CBICA_AVV_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVV_1/BraTS19_CBICA_AVV_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVV_1/BraTS19_CBICA_AVV_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVV_1/BraTS19_CBICA_AVV_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVV_1/BraTS19_CBICA_AVV_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_265_1/BraTS19_TCIA03_265_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_265_1/BraTS19_TCIA03_265_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_265_1/BraTS19_TCIA03_265_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_265_1/BraTS19_TCIA03_265_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_265_1/BraTS19_TCIA03_265_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVT_1/BraTS19_CBICA_AVT_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVT_1/BraTS19_CBICA_AVT_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVT_1/BraTS19_CBICA_AVT_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVT_1/BraTS19_CBICA_AVT_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVT_1/BraTS19_CBICA_AVT_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASV_1/BraTS19_CBICA_ASV_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASV_1/BraTS19_CBICA_ASV_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASV_1/BraTS19_CBICA_ASV_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASV_1/BraTS19_CBICA_ASV_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASV_1/BraTS19_CBICA_ASV_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_11_1/BraTS19_2013_11_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_11_1/BraTS19_2013_11_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_11_1/BraTS19_2013_11_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_11_1/BraTS19_2013_11_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_11_1/BraTS19_2013_11_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_429_1/BraTS19_TCIA01_429_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_429_1/BraTS19_TCIA01_429_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_429_1/BraTS19_TCIA01_429_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_429_1/BraTS19_TCIA01_429_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_429_1/BraTS19_TCIA01_429_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQV_1/BraTS19_CBICA_AQV_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQV_1/BraTS19_CBICA_AQV_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQV_1/BraTS19_CBICA_AQV_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQV_1/BraTS19_CBICA_AQV_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQV_1/BraTS19_CBICA_AQV_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARF_1/BraTS19_CBICA_ARF_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARF_1/BraTS19_CBICA_ARF_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARF_1/BraTS19_CBICA_ARF_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARF_1/BraTS19_CBICA_ARF_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARF_1/BraTS19_CBICA_ARF_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_338_1/BraTS19_TCIA03_338_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_338_1/BraTS19_TCIA03_338_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_338_1/BraTS19_TCIA03_338_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_338_1/BraTS19_TCIA03_338_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_338_1/BraTS19_TCIA03_338_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_375_1/BraTS19_TCIA03_375_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_375_1/BraTS19_TCIA03_375_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_375_1/BraTS19_TCIA03_375_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_375_1/BraTS19_TCIA03_375_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA03_375_1/BraTS19_TCIA03_375_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABO_1/BraTS19_CBICA_ABO_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABO_1/BraTS19_CBICA_ABO_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABO_1/BraTS19_CBICA_ABO_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABO_1/BraTS19_CBICA_ABO_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ABO_1/BraTS19_CBICA_ABO_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASA_1/BraTS19_CBICA_ASA_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASA_1/BraTS19_CBICA_ASA_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASA_1/BraTS19_CBICA_ASA_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASA_1/BraTS19_CBICA_ASA_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ASA_1/BraTS19_CBICA_ASA_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ALU_1/BraTS19_CBICA_ALU_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ALU_1/BraTS19_CBICA_ALU_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ALU_1/BraTS19_CBICA_ALU_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ALU_1/BraTS19_CBICA_ALU_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ALU_1/BraTS19_CBICA_ALU_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_111_1/BraTS19_TCIA04_111_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_111_1/BraTS19_TCIA04_111_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_111_1/BraTS19_TCIA04_111_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_111_1/BraTS19_TCIA04_111_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_111_1/BraTS19_TCIA04_111_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYG_1/BraTS19_CBICA_AYG_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYG_1/BraTS19_CBICA_AYG_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYG_1/BraTS19_CBICA_AYG_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYG_1/BraTS19_CBICA_AYG_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AYG_1/BraTS19_CBICA_AYG_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_14_1/BraTS19_2013_14_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_14_1/BraTS19_2013_14_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_14_1/BraTS19_2013_14_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_14_1/BraTS19_2013_14_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_14_1/BraTS19_2013_14_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQD_1/BraTS19_CBICA_AQD_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQD_1/BraTS19_CBICA_AQD_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQD_1/BraTS19_CBICA_AQD_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQD_1/BraTS19_CBICA_AQD_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AQD_1/BraTS19_CBICA_AQD_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_608_1/BraTS19_TCIA02_608_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_608_1/BraTS19_TCIA02_608_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_608_1/BraTS19_TCIA02_608_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_608_1/BraTS19_TCIA02_608_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_608_1/BraTS19_TCIA02_608_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_277_1/BraTS19_TCIA05_277_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_277_1/BraTS19_TCIA05_277_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_277_1/BraTS19_TCIA05_277_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_277_1/BraTS19_TCIA05_277_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_277_1/BraTS19_TCIA05_277_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARW_1/BraTS19_CBICA_ARW_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARW_1/BraTS19_CBICA_ARW_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARW_1/BraTS19_CBICA_ARW_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARW_1/BraTS19_CBICA_ARW_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ARW_1/BraTS19_CBICA_ARW_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_361_1/BraTS19_TCIA04_361_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_361_1/BraTS19_TCIA04_361_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_361_1/BraTS19_TCIA04_361_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_361_1/BraTS19_TCIA04_361_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA04_361_1/BraTS19_TCIA04_361_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_322_1/BraTS19_TCIA02_322_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_322_1/BraTS19_TCIA02_322_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_322_1/BraTS19_TCIA02_322_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_322_1/BraTS19_TCIA02_322_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA02_322_1/BraTS19_TCIA02_322_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVJ_1/BraTS19_CBICA_AVJ_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVJ_1/BraTS19_CBICA_AVJ_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVJ_1/BraTS19_CBICA_AVJ_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVJ_1/BraTS19_CBICA_AVJ_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AVJ_1/BraTS19_CBICA_AVJ_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_25_1/BraTS19_2013_25_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_25_1/BraTS19_2013_25_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_25_1/BraTS19_2013_25_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_25_1/BraTS19_2013_25_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_2013_25_1/BraTS19_2013_25_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANP_1/BraTS19_CBICA_ANP_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANP_1/BraTS19_CBICA_ANP_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANP_1/BraTS19_CBICA_ANP_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANP_1/BraTS19_CBICA_ANP_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_ANP_1/BraTS19_CBICA_ANP_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BBG_1/BraTS19_CBICA_BBG_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BBG_1/BraTS19_CBICA_BBG_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BBG_1/BraTS19_CBICA_BBG_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BBG_1/BraTS19_CBICA_BBG_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BBG_1/BraTS19_CBICA_BBG_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_180_1/BraTS19_TCIA01_180_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_180_1/BraTS19_TCIA01_180_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_180_1/BraTS19_TCIA01_180_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_180_1/BraTS19_TCIA01_180_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA01_180_1/BraTS19_TCIA01_180_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AUR_1/BraTS19_CBICA_AUR_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AUR_1/BraTS19_CBICA_AUR_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AUR_1/BraTS19_CBICA_AUR_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AUR_1/BraTS19_CBICA_AUR_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_AUR_1/BraTS19_CBICA_AUR_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_396_1/BraTS19_TCIA05_396_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_396_1/BraTS19_TCIA05_396_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_396_1/BraTS19_TCIA05_396_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_396_1/BraTS19_TCIA05_396_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_TCIA05_396_1/BraTS19_TCIA05_396_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGE_1/BraTS19_CBICA_BGE_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGE_1/BraTS19_CBICA_BGE_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGE_1/BraTS19_CBICA_BGE_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/HGG/BraTS19_CBICA_BGE_1/BraTS19_CBICA_BGE_1_t1.nii
# ...
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_442_1/BraTS19_TCIA10_442_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_442_1/BraTS19_TCIA10_442_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_442_1/BraTS19_TCIA10_442_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_615_1/BraTS19_TCIA13_615_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_615_1/BraTS19_TCIA13_615_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_615_1/BraTS19_TCIA13_615_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_615_1/BraTS19_TCIA13_615_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_615_1/BraTS19_TCIA13_615_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_640_1/BraTS19_TCIA10_640_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_640_1/BraTS19_TCIA10_640_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_640_1/BraTS19_TCIA10_640_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_640_1/BraTS19_TCIA10_640_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_640_1/BraTS19_TCIA10_640_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_175_1/BraTS19_TCIA10_175_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_175_1/BraTS19_TCIA10_175_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_175_1/BraTS19_TCIA10_175_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_175_1/BraTS19_TCIA10_175_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_175_1/BraTS19_TCIA10_175_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_152_1/BraTS19_TCIA10_152_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_152_1/BraTS19_TCIA10_152_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_152_1/BraTS19_TCIA10_152_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_152_1/BraTS19_TCIA10_152_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_152_1/BraTS19_TCIA10_152_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_642_1/BraTS19_TCIA13_642_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_642_1/BraTS19_TCIA13_642_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_642_1/BraTS19_TCIA13_642_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_642_1/BraTS19_TCIA13_642_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_642_1/BraTS19_TCIA13_642_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_653_1/BraTS19_TCIA13_653_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_653_1/BraTS19_TCIA13_653_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_653_1/BraTS19_TCIA13_653_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_653_1/BraTS19_TCIA13_653_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_653_1/BraTS19_TCIA13_653_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_623_1/BraTS19_TCIA13_623_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_623_1/BraTS19_TCIA13_623_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_623_1/BraTS19_TCIA13_623_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_623_1/BraTS19_TCIA13_623_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_623_1/BraTS19_TCIA13_623_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_28_1/BraTS19_2013_28_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_28_1/BraTS19_2013_28_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_28_1/BraTS19_2013_28_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_28_1/BraTS19_2013_28_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_28_1/BraTS19_2013_28_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_15_1/BraTS19_2013_15_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_15_1/BraTS19_2013_15_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_15_1/BraTS19_2013_15_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_15_1/BraTS19_2013_15_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_15_1/BraTS19_2013_15_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_346_1/BraTS19_TCIA10_346_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_346_1/BraTS19_TCIA10_346_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_346_1/BraTS19_TCIA10_346_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_346_1/BraTS19_TCIA10_346_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_346_1/BraTS19_TCIA10_346_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TMC_09043_1/BraTS19_TMC_09043_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TMC_09043_1/BraTS19_TMC_09043_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TMC_09043_1/BraTS19_TMC_09043_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TMC_09043_1/BraTS19_TMC_09043_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TMC_09043_1/BraTS19_TMC_09043_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_282_1/BraTS19_TCIA10_282_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_282_1/BraTS19_TCIA10_282_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_282_1/BraTS19_TCIA10_282_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_282_1/BraTS19_TCIA10_282_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_282_1/BraTS19_TCIA10_282_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_449_1/BraTS19_TCIA10_449_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_449_1/BraTS19_TCIA10_449_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_449_1/BraTS19_TCIA10_449_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_449_1/BraTS19_TCIA10_449_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_449_1/BraTS19_TCIA10_449_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_466_1/BraTS19_TCIA12_466_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_466_1/BraTS19_TCIA12_466_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_466_1/BraTS19_TCIA12_466_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_466_1/BraTS19_TCIA12_466_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_466_1/BraTS19_TCIA12_466_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA09_141_1/BraTS19_TCIA09_141_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA09_141_1/BraTS19_TCIA09_141_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA09_141_1/BraTS19_TCIA09_141_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA09_141_1/BraTS19_TCIA09_141_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA09_141_1/BraTS19_TCIA09_141_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_101_1/BraTS19_TCIA12_101_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_101_1/BraTS19_TCIA12_101_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_101_1/BraTS19_TCIA12_101_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_101_1/BraTS19_TCIA12_101_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA12_101_1/BraTS19_TCIA12_101_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_241_1/BraTS19_TCIA10_241_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_241_1/BraTS19_TCIA10_241_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_241_1/BraTS19_TCIA10_241_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_241_1/BraTS19_TCIA10_241_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_241_1/BraTS19_TCIA10_241_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_325_1/BraTS19_TCIA10_325_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_325_1/BraTS19_TCIA10_325_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_325_1/BraTS19_TCIA10_325_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_325_1/BraTS19_TCIA10_325_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA10_325_1/BraTS19_TCIA10_325_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_29_1/BraTS19_2013_29_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_29_1/BraTS19_2013_29_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_29_1/BraTS19_2013_29_1_t1ce.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_29_1/BraTS19_2013_29_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_2013_29_1/BraTS19_2013_29_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_621_1/BraTS19_TCIA13_621_1_t2.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_621_1/BraTS19_TCIA13_621_1_t1.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_621_1/BraTS19_TCIA13_621_1_flair.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_621_1/BraTS19_TCIA13_621_1_seg.nii
# /kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training/LGG/BraTS19_TCIA13_621_1/BraTS19_TCIA13_621_1_t1ce.nii

# %%
# !pip install nibabel
# Out:
# Requirement already satisfied: nibabel in /usr/local/lib/python3.12/dist-packages (5.3.3)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.12/dist-packages (from nibabel) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from nibabel) (26.0)
# Requirement already satisfied: typing-extensions>=4.6 in /usr/local/lib/python3.12/dist-packages (from nibabel) (4.15.0)

# %%
# !pip install antspyx
# !pip install torchvision
# Out:
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8f49c7baa0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/antspyx/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7f8f496f48f0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/antspyx/
# ^C
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (0.25.0+cpu)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: torch==2.10.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (2.10.0+cpu)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (3.24.3)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch==2.10.0->torchvision) (2026.2.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.10.0->torchvision) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.10.0->torchvision) (3.0.3)
# ^C
# ERROR: Operation cancelled by user

# %%
import os
import random
import numpy as np
import nibabel as nib
import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader
from skimage.metrics import structural_similarity as ssim
import matplotlib.pyplot as plt
import ants
import torchvision.models as models

DATA_ROOT = "/kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training"
SAVE_DIR  = "/kaggle/working/outputs"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BATCH_SIZE = 2
EPOCHS = 60
LR = 1e-4
NUM_CASES  = 40
NUM_SLICES = 32

os.makedirs(SAVE_DIR, exist_ok=True)

def normalize(img):
    img = img - np.min(img)
    img = img / (np.max(img) + 1e-8)
    return img

def center_crop(img, size=192):
    h, w = img.shape
    s = size // 2
    return img[h//2-s:h//2+s, w//2-s:w//2+s]

def compute_psnr(pred, target):
    mse = np.mean((pred-target)**2)
    return 10*np.log10(1.0/(mse+1e-8))

def compute_ssim(pred, target):
    return ssim(pred, target, data_range=pred.max()-pred.min())

def register_to_flair(moving, fixed):

    moving_img = ants.from_numpy(moving)
    fixed_img  = ants.from_numpy(fixed)

    tx = ants.registration(fixed=fixed_img, moving=moving_img, type_of_transform="Affine")

    warped = ants.apply_transforms(
        fixed=fixed_img,
        moving=moving_img,
        transformlist=tx['fwdtransforms']
    )

    return warped.numpy()

class BraTSDataset(Dataset):
    def __init__(self, root):

        self.data=[]
        all_cases=[]

        for folder in ["HGG","LGG"]:
            path=os.path.join(root,folder)
            if os.path.exists(path):
                all_cases += [os.path.join(path,c) for c in os.listdir(path)]

        all_cases=all_cases[:NUM_CASES]

        print("Registering modalities...")

        for case in all_cases:

            files=os.listdir(case)

            t1=t2=t1ce=flair=None
            for f in files:
                name=f.lower()
                if "_t1." in name and "ce" not in name: t1=f
                elif "_t2." in name: t2=f
                elif "t1ce" in name: t1ce=f
                elif "flair" in name: flair=f

            if None in [t1,t2,t1ce,flair]: continue

            flair_vol=nib.load(os.path.join(case,flair)).get_fdata(dtype=np.float32)

            vols=[]
            for fname in [t1,t2,t1ce]:

                moving=nib.load(os.path.join(case,fname)).get_fdata(dtype=np.float32)
                registered=register_to_flair(moving, flair_vol)

                z=registered.shape[2]
                start=(z-NUM_SLICES)//2
                vols.append(registered[:,:,start:start+NUM_SLICES])

            z=flair_vol.shape[2]
            start=(z-NUM_SLICES)//2
            vols.append(flair_vol[:,:,start:start+NUM_SLICES])

            self.data.append(vols)

    def __len__(self):
        return len(self.data)*NUM_SLICES

    def __getitem__(self, idx):

        case_id=idx//NUM_SLICES
        slice_id=idx%NUM_SLICES

        vols=self.data[case_id]

        imgs=[]
        for vol in vols:
            img=center_crop(vol[:,:,slice_id])
            imgs.append(normalize(img))

        imgs=np.stack(imgs)
        gt=imgs.copy()

        imgs=torch.from_numpy(imgs).float().unsqueeze(1)
        gt=torch.from_numpy(gt).float().unsqueeze(1)

        ac=torch.ones(4)
        miss=random.randint(1,3)
        idxs=random.sample(range(4),miss)
        for i in idxs:
            ac[i]=0
            imgs[i]=0

        return imgs,ac,gt

vgg=models.vgg16(pretrained=True).features[:16].to(DEVICE).eval()
for p in vgg.parameters(): p.requires_grad=False

def perceptual_loss(pred, target):
    pred3 = pred.repeat(1,3,1,1)
    target3 = target.repeat(1,3,1,1)
    return nn.L1Loss()(vgg(pred3), vgg(target3))


class ConvBlock(nn.Module):
    def __init__(self,in_c,out_c):
        super().__init__()
        self.block=nn.Sequential(
            nn.Conv2d(in_c,out_c,3,padding=1),
            nn.InstanceNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self,x): return self.block(x)

class Encoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.blocks=nn.ModuleList([
            ConvBlock(1,16),
            ConvBlock(16,32),
            ConvBlock(32,64)
        ])
        self.pool=nn.MaxPool2d(2)

    def forward(self,x):
        feats=[]
        for b in self.blocks:
            x=b(x)
            feats.append(x)
            x=self.pool(x)
        return feats

class DFUM(nn.Module):
    def __init__(self,c):
        super().__init__()
        self.att3=nn.Conv2d(c,c,3,1,1)
        self.att5=nn.Conv2d(c,c,5,1,2)
        self.att7=nn.Conv2d(c,c,7,1,3)
        self.fuse=nn.Conv2d(2*c,c,1)

    def forward(self,feats,ac):
        mask=ac.view(-1,1,1,1)
        valid=[feats[i]*mask[i] for i in range(len(feats))]
        valid=torch.stack(valid)

        hard=torch.max(valid,dim=0)[0]

        att=[self.att3(f)+self.att5(f)+self.att7(f) for f in valid]
        w=torch.softmax(torch.stack(att),dim=0)

        soft=sum(wi*fi for wi,fi in zip(w,valid))
        return self.fuse(torch.cat([hard,soft],1))

class Decoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.up=nn.Upsample(scale_factor=2)
        self.blocks=nn.ModuleList([
            ConvBlock(64,32),
            ConvBlock(32,16)
        ])
        self.out=nn.Conv2d(16,1,1)

    def forward(self,feats):
        x=feats[-1]
        for b in self.blocks:
            x=self.up(x)
            x=b(x)
        return self.out(x)

class Generator(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc=nn.ModuleList([Encoder() for _ in range(4)])
        self.dfums=nn.ModuleList([DFUM(16),DFUM(32),DFUM(64)])
        self.dec=nn.ModuleList([Decoder() for _ in range(4)])

    def forward(self,x,ac):
        spec=[self.enc[i](x[i]) for i in range(4)]
        unified=[]
        for s in range(3):
            feats=[spec[i][s] for i in range(4)]
            unified.append(self.dfums[s](feats,ac))
        outputs=[d(unified) for d in self.dec]
        return torch.sigmoid(torch.stack(outputs))

class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.net=nn.Sequential(
            nn.Conv2d(1,32,4,2,1),
            nn.LeakyReLU(0.2),
            nn.Conv2d(32,64,4,2,1),
            nn.InstanceNorm2d(64),
            nn.LeakyReLU(0.2),
            nn.Conv2d(64,128,4,2,1),
            nn.InstanceNorm2d(128),
            nn.LeakyReLU(0.2),
            nn.Conv2d(128,1,4,1,1)
        )
    def forward(self,x): return self.net(x)

# ================= IMAGE SAVE =================

def denormalize(x):
    x = (x + 1) / 2   # convert from [-1,1] → [0,1]
    return np.clip(x, 0, 1)

def enhance_contrast(img):
    p2, p98 = np.percentile(img, (2, 98))
    img = np.clip((img - p2) / (p98 - p2 + 1e-8), 0, 1)
    return img

def save_sample(imgs, fake, ac, epoch):

    imgs = imgs.cpu()
    fake = fake.cpu()
    ac   = ac.cpu()

    names = ['T1','T2','T1CE','FLAIR']

    for i in range(4):

        inp = imgs[i,0,0].numpy()
        syn = fake[i,0,0].detach().numpy()

        inp = enhance_contrast(denormalize(inp))
        syn = enhance_contrast(denormalize(syn))

        status = "Missing" if ac[i]==0 else "Present"

        fig,ax=plt.subplots(1,2,figsize=(6,3))

        ax[0].imshow(inp, cmap="gray", vmin=0, vmax=1)
        ax[0].set_title(f"{names[i]} Input ({status})")
        ax[0].axis("off")

        ax[1].imshow(syn, cmap="gray", vmin=0, vmax=1)
        ax[1].set_title(f"{names[i]} Synth")
        ax[1].axis("off")

        plt.tight_layout()
        plt.savefig(f"{SAVE_DIR}/epoch{epoch}_{names[i]}.png")
        plt.close()


MSE=nn.MSELoss()
def g_loss(fake): return MSE(fake,torch.ones_like(fake))
def d_loss(real,fake): return 0.5*(MSE(real,torch.ones_like(real))+MSE(fake,torch.zeros_like(fake)))

def compute_psnr(pred, target):
    mse = np.mean((pred-target)**2)
    return 10*np.log10(1.0/(mse+1e-8))

def compute_ssim(pred, target):
    return ssim(pred, target, data_range=pred.max()-pred.min())


dataset=BraTSDataset(DATA_ROOT)
loader=DataLoader(dataset,batch_size=BATCH_SIZE,shuffle=True)

netG=Generator().to(DEVICE)
optG=torch.optim.Adam(netG.parameters(),lr=LR)

L1=nn.L1Loss()
SSIM_L = lambda x,y: 1 - torch.mean(torch.tensor([
    compute_ssim(x[i,0].cpu().detach().numpy(), y[i,0].cpu().detach().numpy())
    for i in range(x.shape[0])
]).to(DEVICE))


for epoch in range(EPOCHS):

    netG.train()

    for imgs,ac,gt in loader:

        imgs=imgs.to(DEVICE)
        ac=ac.to(DEVICE)
        gt=gt.to(DEVICE)

        imgs=imgs.permute(1,0,2,3,4)
        gt=gt.permute(1,0,2,3,4)

        fake=netG(imgs,ac[0])

        loss_syn=sum((1-ac[0,i])*L1(fake[i],gt[i]) for i in range(4))
        loss_rec=sum(ac[0,i]*L1(fake[i],gt[i]) for i in range(4))
        loss_per=sum(perceptual_loss(fake[i],gt[i]) for i in range(4))

        loss_ssim = sum(SSIM_L(fake[i], gt[i]) for i in range(4))
        lossG = 50*loss_syn + 20*loss_rec + 20*loss_per + 10*loss_ssim


        optG.zero_grad()
        lossG.backward()
        optG.step()

    netG.eval()
    psnr_vals=[]
    ssim_vals=[]

    with torch.no_grad():

        for imgs,ac,gt in loader:

            imgs=imgs.to(DEVICE)
            ac=ac.to(DEVICE)
            gt=gt.to(DEVICE)

            imgs=imgs.permute(1,0,2,3,4)
            gt=gt.permute(1,0,2,3,4)

            fake=netG(imgs,ac[0])

            for i in range(4):
                if ac[0,i]==0:

                    pred=fake[i][0,0].cpu().numpy()
                    target=gt[i][0,0].cpu().numpy()

                    psnr_vals.append(compute_psnr(pred,target))
                    ssim_vals.append(compute_ssim(pred,target))

            save_sample(imgs, fake, ac[0], epoch)

            break

    print(f"Epoch {epoch} | PSNR {np.mean(psnr_vals):.2f} | SSIM {np.mean(ssim_vals):.4f}")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_57/3478760414.py in <cell line: 0>()
#       8 from skimage.metrics import structural_similarity as ssim
#       9 import matplotlib.pyplot as plt
# ---> 10 import ants
#      11 import torchvision.models as models
#      12
#
# ModuleNotFoundError: No module named 'ants'

# %%
import shutil

shutil.make_archive('/kaggle/working/synth_outputs', 'zip', SAVE_DIR)
# Out:
# '/kaggle/working/synth_outputs.zip'

# %%
import os
import numpy as np
import nibabel as nib
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import torch.optim as optim
import matplotlib.pyplot as plt

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
PATCH_SIZE = 48

# =========================
# 🔥 TUMOR-FOCUSED CROP
# =========================
def tumor_crop(img, mask, size=48):
    _, H, W, D = img.shape

    coords = np.argwhere(mask > 0)

    if len(coords) > 0:
        center = coords[np.random.choice(len(coords))]
        h, w, d = center

        h = np.clip(h - size//2, 0, H - size)
        w = np.clip(w - size//2, 0, W - size)
        d = np.clip(d - size//2, 0, D - size)
    else:
        h = np.random.randint(0, H - size)
        w = np.random.randint(0, W - size)
        d = np.random.randint(0, D - size)

    return (
        img[:, h:h+size, w:w+size, d:d+size],
        mask[h:h+size, w:w+size, d:d+size]
    )

# =========================
# 📌 DATASET
# =========================
class BraTSDataset(Dataset):
    def __init__(self, root_dir):
        self.samples = []

        for subdir, _, files in os.walk(root_dir):
            if any("_flair.nii" in f for f in files):
                self.samples.append(subdir)

    def __len__(self):
        return len(self.samples)

    def normalize(self, img):
        if np.std(img) != 0:
            img = (img - np.mean(img)) / np.std(img)
        return img

    def __getitem__(self, idx):
        path = self.samples[idx]

        def load(name):
            file = [f for f in os.listdir(path) if name in f][0]
            return nib.load(os.path.join(path, file)).get_fdata()

        t1 = self.normalize(load("_t1.nii"))
        t1ce = self.normalize(load("_t1ce.nii"))
        t2 = self.normalize(load("_t2.nii"))
        flair = self.normalize(load("_flair.nii"))
        seg = load("_seg.nii")

        seg[seg == 4] = 3

        image = np.stack([t1, t1ce, t2, flair], axis=0)

        # 🔥 MIXED SAMPLING (BEST)
        if np.random.rand() > 0.5:
            image, seg = tumor_crop(image, seg, PATCH_SIZE)
        else:
            image, seg = tumor_crop(image, seg, PATCH_SIZE)

        return (
            torch.tensor(image, dtype=torch.float32),
            torch.tensor(seg, dtype=torch.long),
            path
        )

# =========================
# 📌 MODEL (SAFE VERSION)
# =========================
class DoubleConv(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv3d(in_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
            nn.ReLU(inplace=True),
            nn.Conv3d(out_ch, out_ch, 3, padding=1),
            nn.BatchNorm3d(out_ch),
            nn.ReLU(inplace=True)
        )

    def forward(self, x):
        return self.conv(x)

class Down(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.pool = nn.MaxPool3d(2)
        self.conv = DoubleConv(in_ch, out_ch)

    def forward(self, x):
        return self.conv(self.pool(x))

class Up(nn.Module):
    def __init__(self, in_ch, out_ch):
        super().__init__()
        self.up = nn.ConvTranspose3d(in_ch, in_ch // 2, 2, stride=2)
        self.conv = DoubleConv(in_ch, out_ch)

    def forward(self, x1, x2):
        x1 = self.up(x1)

        diffZ = x2.size()[2] - x1.size()[2]
        diffY = x2.size()[3] - x1.size()[3]
        diffX = x2.size()[4] - x1.size()[4]

        x1 = F.pad(x1, [diffX//2, diffX - diffX//2,
                        diffY//2, diffY - diffY//2,
                        diffZ//2, diffZ - diffZ//2])

        x = torch.cat([x2, x1], dim=1)
        return self.conv(x)

class UNet3D(nn.Module):
    def __init__(self):
        super().__init__()

        self.inc = DoubleConv(4, 8)
        self.down1 = Down(8, 16)
        self.down2 = Down(16, 32)

        self.up1 = Up(32, 16)
        self.up2 = Up(16, 8)

        self.outc = nn.Conv3d(8, 4, 1)

    def forward(self, x):
        x1 = self.inc(x)
        x2 = self.down1(x1)
        x3 = self.down2(x2)

        x = self.up1(x3, x2)
        x = self.up2(x, x1)

        return self.outc(x)

# =========================
# 📌 LOSS
# =========================
class DiceLoss(nn.Module):
    def forward(self, logits, targets):
        probs = torch.softmax(logits, dim=1)
        targets_onehot = F.one_hot(targets, num_classes=4).permute(0,4,1,2,3).float()

        intersection = torch.sum(probs * targets_onehot)
        union = torch.sum(probs) + torch.sum(targets_onehot)

        return 1 - (2 * intersection + 1e-5) / (union + 1e-5)

class SegLoss(nn.Module):
    def __init__(self):
        super().__init__()
        self.ce = nn.CrossEntropyLoss()
        self.dice = DiceLoss()

    def forward(self, logits, targets):
        return self.ce(logits, targets) + self.dice(logits, targets)

# =========================
# 📌 TRAIN
# =========================
def train(model, loader, optimizer, loss_fn, epochs=5):
    scaler = torch.amp.GradScaler("cuda")

    for epoch in range(epochs):
        model.train()
        total_loss = 0

        for img, mask, _ in loader:
            img, mask = img.to(DEVICE), mask.to(DEVICE)

            optimizer.zero_grad()

            with torch.amp.autocast("cuda"):
                out = model(img)
                loss = loss_fn(out, mask)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            total_loss += loss.item()

        print(f"Epoch {epoch+1}, Loss: {total_loss/len(loader):.4f}")

# =========================
# 📌 SAVE PNG OUTPUT
# =========================
def save_predictions(model, loader, output_dir):
    os.makedirs(output_dir, exist_ok=True)
    model.eval()

    with torch.no_grad():
        for img, mask, path in loader:
            img = img.to(DEVICE)

            out = model(img)
            pred = torch.argmax(out, dim=1).cpu().numpy()[0]
            mask = mask.numpy()[0]

            slice_idx = pred.shape[2] // 2

            fig, axs = plt.subplots(1, 3, figsize=(12, 4))

            axs[0].imshow(img.cpu().numpy()[0, 0, :, :, slice_idx], cmap="gray")
            axs[0].set_title("Input")

            axs[1].imshow(mask[:, :, slice_idx], cmap="jet")
            axs[1].set_title("GT")

            axs[2].imshow(pred[:, :, slice_idx], cmap="jet")
            axs[2].set_title("Pred")

            for ax in axs:
                ax.axis("off")

            name = os.path.basename(path[0])
            save_path = os.path.join(output_dir, name + ".png")

            plt.savefig(save_path, bbox_inches='tight')
            plt.close()

            print("Saved:", save_path)

# =========================
# 🚀 MAIN
# =========================
if __name__ == "__main__":

    dataset_path = "/kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training"
    output_dir = "/kaggle/working/output1"

    dataset = BraTSDataset(dataset_path)

    # 🔥 LIMIT DATA (FOR KAGGLE)
    dataset.samples = dataset.samples[:50]

    loader = DataLoader(dataset, batch_size=1, shuffle=True, num_workers=0)

    model = UNet3D().to(DEVICE)
    optimizer = optim.Adam(model.parameters(), lr=1e-4)
    loss_fn = SegLoss()

    torch.cuda.empty_cache()

    print("Training...")
    train(model, loader, optimizer, loss_fn, epochs=5)

    print("Saving predictions...")
    save_predictions(model, loader, output_dir)

    print("Done!")
# Out:
# Training...
# Epoch 1, Loss: 1.9671
# Epoch 2, Loss: 1.7341
# Epoch 3, Loss: 1.6559
# Epoch 4, Loss: 1.6034
# Epoch 5, Loss: 1.5674
# Saving predictions...
# Saved: /kaggle/working/output1/BraTS19_2013_27_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AYG_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA03_265_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_314_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA06_372_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA04_343_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_APR_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AXW_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA08_242_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AWG_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA03_138_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AQP_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA03_338_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ASA_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ASV_1.png
# Saved: /kaggle/working/output1/BraTS19_2013_3_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AVT_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA04_111_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AYA_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AVV_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AQA_1.png
# Saved: /kaggle/working/output1/BraTS19_2013_2_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_BGR_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_BGN_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ALU_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ABO_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA01_412_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_226_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AQD_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ATN_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ANZ_1.png
# Saved: /kaggle/working/output1/BraTS19_2013_11_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA05_444_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_608_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AQZ_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AVF_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ABB_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_321_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ARF_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_331_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA03_375_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA01_429_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA03_199_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ATD_1.png
# Saved: /kaggle/working/output1/BraTS19_2013_14_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AQV_1.png
# Saved: /kaggle/working/output1/BraTS19_TCIA02_222_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ASH_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_ARZ_1.png
# Saved: /kaggle/working/output1/BraTS19_CBICA_AAP_1.png
# Done!

# %%
# ================= IMPORTS =================
import os, random
import numpy as np
import nibabel as nib
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import matplotlib.pyplot as plt

# ================= CONFIG =================
DATA_ROOT = "/kaggle/input/datasets/aryashah2k/brain-tumor-segmentation-brats-2019/MICCAI_BraTS_2019_Data_Training"
SAVE_DIR  = "/kaggle/working/seg_outputs"
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

BATCH_SIZE = 4
EPOCHS = 40
LR = 1e-4
NUM_CASES  = 80
NUM_SLICES = 32

os.makedirs(SAVE_DIR, exist_ok=True)

# ================= UTILS =================
def normalize(img):
    img = img - np.min(img)
    img = img / (np.max(img) + 1e-8)
    return img

def center_crop(img, size=192):
    h, w = img.shape
    s = size // 2
    return img[h//2-s:h//2+s, w//2-s:w//2+s]

# ================= DATASET =================
class BraTSSegDataset(Dataset):
    def __init__(self, root):
        self.data = []
        all_cases = []

        for folder in ["HGG", "LGG"]:
            path = os.path.join(root, folder)
            if os.path.exists(path):
                all_cases += [os.path.join(path, c) for c in os.listdir(path)]

        all_cases = all_cases[:NUM_CASES]

        for case in all_cases:
            files = os.listdir(case)

            t1=t2=t1ce=flair=seg=None
            for f in files:
                name=f.lower()
                if "_t1." in name and "ce" not in name: t1=f
                elif "_t2." in name: t2=f
                elif "t1ce" in name: t1ce=f
                elif "flair" in name: flair=f
                elif "seg" in name: seg=f

            if None in [t1,t2,t1ce,flair,seg]:
                continue

            vols=[]
            for fname in [t1,t2,t1ce,flair]:
                vol = nib.load(os.path.join(case,fname)).get_fdata(dtype=np.float32)
                z = vol.shape[2]
                start = (z-NUM_SLICES)//2
                vols.append(vol[:,:,start:start+NUM_SLICES])

            seg_vol = nib.load(os.path.join(case,seg)).get_fdata(dtype=np.float32)
            seg_vol[seg_vol == 4] = 3   # 🔥 FIX LABEL

            z = seg_vol.shape[2]
            start = (z-NUM_SLICES)//2
            seg_vol = seg_vol[:,:,start:start+NUM_SLICES]

            self.data.append((vols, seg_vol))

    def __len__(self):
        return len(self.data) * NUM_SLICES

    def __getitem__(self, idx):
        case_id = idx // NUM_SLICES
        slice_id = idx % NUM_SLICES

        vols, seg_vol = self.data[case_id]

        imgs=[]
        for vol in vols:
            img = center_crop(vol[:,:,slice_id])
            imgs.append(normalize(img))

        imgs = np.stack(imgs)   # (4,H,W)
        mask = center_crop(seg_vol[:,:,slice_id])

        imgs = torch.from_numpy(imgs).float()
        mask = torch.from_numpy(mask).long()   # 🔥 MULTI-CLASS

        return imgs, mask

# ================= MODEL =================
class ConvBlock(nn.Module):
    def __init__(self, in_c, out_c):
        super().__init__()
        self.block = nn.Sequential(
            nn.Conv2d(in_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True),
            nn.Conv2d(out_c, out_c, 3, padding=1),
            nn.BatchNorm2d(out_c),
            nn.ReLU(inplace=True)
        )
    def forward(self, x): return self.block(x)

class UNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.enc1 = ConvBlock(4,32)
        self.enc2 = ConvBlock(32,64)
        self.enc3 = ConvBlock(64,128)
        self.pool = nn.MaxPool2d(2)

        self.up1 = nn.ConvTranspose2d(128,64,2,2)
        self.dec1 = ConvBlock(128,64)
        self.up2 = nn.ConvTranspose2d(64,32,2,2)
        self.dec2 = ConvBlock(64,32)

        self.out = nn.Conv2d(32,4,1)   # 🔥 MULTI-CLASS

    def forward(self,x):
        x1 = self.enc1(x)
        x2 = self.enc2(self.pool(x1))
        x3 = self.enc3(self.pool(x2))

        x = self.up1(x3)
        x = self.dec1(torch.cat([x,x2],1))
        x = self.up2(x)
        x = self.dec2(torch.cat([x,x1],1))

        return self.out(x)   # NO sigmoid

# ================= LOSS =================
CE = nn.CrossEntropyLoss()

def multiclass_dice_loss(pred, target, num_classes=4):
    pred = torch.softmax(pred, dim=1)
    target_onehot = F.one_hot(target, num_classes).permute(0,3,1,2).float()

    intersection = (pred * target_onehot).sum(dim=(2,3))
    union = pred.sum(dim=(2,3)) + target_onehot.sum(dim=(2,3))

    dice = (2*intersection + 1e-5) / (union + 1e-5)
    return 1 - dice.mean()

# ================= TRAIN =================
dataset = BraTSSegDataset(DATA_ROOT)
loader  = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True)

model = UNet().to(DEVICE)
opt = torch.optim.Adam(model.parameters(), lr=LR)

for epoch in range(EPOCHS):

    model.train()
    for imgs,mask in loader:
        imgs = imgs.to(DEVICE)
        mask = mask.to(DEVICE)

        pred = model(imgs)

        loss = CE(pred, mask) + multiclass_dice_loss(pred, mask)

        opt.zero_grad()
        loss.backward()
        opt.step()

    # ===== Evaluation =====
    model.eval()

    with torch.no_grad():
        for imgs,mask in loader:
            imgs = imgs.to(DEVICE)
            mask = mask.to(DEVICE)

            pred = model(imgs)
            pred_cls = torch.argmax(pred, dim=1)

            # visualize
            p = pred_cls[0].cpu().numpy()
            m = mask[0].cpu().numpy()
            i = imgs[0,0].cpu().numpy()

            fig,ax = plt.subplots(1,3,figsize=(12,4))
            ax[0].imshow(i,cmap="gray"); ax[0].set_title("Input")
            ax[1].imshow(m,cmap="jet"); ax[1].set_title("GT")
            ax[2].imshow(p,cmap="jet"); ax[2].set_title("Pred")

            for a in ax: a.axis("off")

            plt.savefig(f"{SAVE_DIR}/epoch_{epoch}.png")
            plt.close()
            break

    print(f"Epoch {epoch} done")
# Out:
# Epoch 0 done
# Epoch 1 done
# Epoch 2 done
# Epoch 3 done
# Epoch 4 done
# Epoch 5 done
# Epoch 6 done
# Epoch 7 done
# Epoch 8 done
# Epoch 9 done
# Epoch 10 done
# Epoch 11 done
# Epoch 12 done
# Epoch 13 done
# Epoch 14 done
# Epoch 15 done
# Epoch 16 done
# Epoch 17 done
# Epoch 18 done
# Epoch 19 done
# Epoch 20 done
# Epoch 21 done
# Epoch 22 done
# Epoch 23 done
# Epoch 24 done
# Epoch 25 done
# Epoch 26 done
# Epoch 27 done
# Epoch 28 done
# Epoch 29 done
# Epoch 30 done
# Epoch 31 done
# Epoch 32 done
# Epoch 33 done
# Epoch 34 done
# Epoch 35 done
# Epoch 36 done
# Epoch 37 done
# Epoch 38 done
# Epoch 39 done

# %%
import torch

# =========================
# 🧠 BASIC DICE FUNCTION
# =========================
def dice_score(pred, target, eps=1e-5):
    intersection = (pred * target).sum()
    union = pred.sum() + target.sum()
    return (2 * intersection + eps) / (union + eps)


# =========================
# 🔥 MULTI-CLASS DICE (BRATS)
# =========================
def compute_brats_dice(pred, target):
    """
    pred, target: numpy or torch tensors of shape (H, W)
    values: 0,1,2,3
    """

    if isinstance(pred, torch.Tensor):
        pred = pred.cpu()
    if isinstance(target, torch.Tensor):
        target = target.cpu()

    # Whole Tumor (WT): labels 1,2,3
    pred_wt = (pred > 0).float()
    target_wt = (target > 0).float()

    # Tumor Core (TC): labels 1,3
    pred_tc = ((pred == 1) | (pred == 3)).float()
    target_tc = ((target == 1) | (target == 3)).float()

    # Enhancing Tumor (ET): label 3
    pred_et = (pred == 3).float()
    target_et = (target == 3).float()

    dice_wt = dice_score(pred_wt, target_wt)
    dice_tc = dice_score(pred_tc, target_tc)
    dice_et = dice_score(pred_et, target_et)

    return {
        "WT": dice_wt.item(),
        "TC": dice_tc.item(),
        "ET": dice_et.item()
    }

# %%
model.eval()

total_wt, total_tc, total_et = 0, 0, 0
count = 0

with torch.no_grad():
    for imgs, mask in loader:

        imgs = imgs.to(DEVICE)
        mask = mask.to(DEVICE)

        # 🔥 THIS LINE WAS MISSING
        output = model(imgs)

        pred = torch.argmax(output, dim=1)

        scores = compute_brats_dice(pred[0], mask[0])

        total_wt += scores["WT"]
        total_tc += scores["TC"]
        total_et += scores["ET"]
        count += 1

print("Average Dice:")
print("WT:", total_wt / count)
print("TC:", total_tc / count)
print("ET:", total_et / count)
# Out:
# Average Dice:
# WT: 0.8854083571483888
# TC: 0.9126755346210288
# ET: 0.8850399062787316
